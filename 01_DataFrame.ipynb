# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
df=pd.read_csv("weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0          6   Rain
# 1  1/2/2017         35.0          7  Sunny
# 2  1/3/2017         28.0          2   Snow
# 3  1/4/2017         24.0          7   Snow
# 4  1/5/2017         32.0          4   Rain
# 5  1/6/2017         31.0          2  Sunny
# 6  1/7/2017          NaN          3   Rain

# %%
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0          6   Rain
# 1  1/2/2017         35.0          7  Sunny
# 2  1/3/2017         28.0          2   Snow
# 3  1/4/2017         24.0          7   Snow
# 4  1/5/2017         32.0          4   Rain

# %%
df.tail()
# Out:
#         day  temperature  windspeed  event
# 2  1/3/2017         28.0          2   Snow
# 3  1/4/2017         24.0          7   Snow
# 4  1/5/2017         32.0          4   Rain
# 5  1/6/2017         31.0          2  Sunny
# 6  1/7/2017          NaN          3   Rain

# %%
df.shape
# Out:
# (7, 4)

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0          6   Rain
# 1  1/2/2017         35.0          7  Sunny

# %%
df.tail(1)
# Out:
#         day  temperature  windspeed event
# 6  1/7/2017          NaN          3  Rain

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017         28.0          2  Snow
# 3  1/4/2017         24.0          7  Snow
# 4  1/5/2017         32.0          4  Rain

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# 6    1/7/2017
# Name: day, dtype: object

# %%
df.event
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# 6     Rain
# Name: event, dtype: object

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['event','day']]
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  Sunny  1/2/2017
# 2   Snow  1/3/2017
# 3   Snow  1/4/2017
# 4   Rain  1/5/2017
# 5  Sunny  1/6/2017
# 6   Rain  1/7/2017

# %%
df['temperature'].max()
# Out:
# np.float64(35.0)

# %%
df['temperature'].min()
# Out:
# np.float64(24.0)

# %%
df['temperature'].mean()
# Out:
# np.float64(30.333333333333332)

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   7.000000
# mean     30.333333   4.428571
# std       3.829708   2.225395
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   4.000000
# 75%      32.000000   6.500000
# max      35.000000   7.000000

# %%
df[df['temperature']>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0          6   Rain
# 1  1/2/2017         35.0          7  Sunny
# 4  1/5/2017         32.0          4   Rain

# %%
df[df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017         35.0          7  Sunny

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0          6   Rain
# 1  1/2/2017         35.0          7  Sunny
# 2  1/3/2017         28.0          2   Snow
# 3  1/4/2017         24.0          7   Snow
# 4  1/5/2017         32.0          4   Rain
# 5  1/6/2017         31.0          2  Sunny
# 6  1/7/2017          NaN          3   Rain

# %%
df.set_index('day',inplace=True)
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017         32.0          6   Rain
# 1/2/2017         35.0          7  Sunny
# 1/3/2017         28.0          2   Snow
# 1/4/2017         24.0          7   Snow
# 1/5/2017         32.0          4   Rain
# 1/6/2017         31.0          2  Sunny
# 1/7/2017          NaN          3   Rain

# %%
df.reset_index(inplace=True)

# %%
df.set_index('event',inplace=True)
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017         32.0          6
# Sunny  1/2/2017         35.0          7
# Snow   1/3/2017         28.0          2
# Snow   1/4/2017         24.0          7
# Rain   1/5/2017         32.0          4
# Sunny  1/6/2017         31.0          2
# Rain   1/7/2017          NaN          3

# %%
df.loc['Snow']
# Out:
#             day  temperature  windspeed
# event
# Snow   1/3/2017         28.0          2
# Snow   1/4/2017         24.0          7

# %%
df.reset_index(inplace=True)

# %%
df.iloc[0]
# Out:
# event              Rain
# day            1/1/2017
# temperature        32.0
# windspeed             6
# Name: 0, dtype: object

# %%
df[df['temperature']>=35]
# Out:
#    event       day  temperature  windspeed
# 1  Sunny  1/2/2017         35.0          7

# %%
df[df['event']=="Rain"]
# Out:
#   event       day  temperature  windspeed
# 0  Rain  1/1/2017         32.0          6
# 4  Rain  1/5/2017         32.0          4
# 6  Rain  1/7/2017          NaN          3

# %%
df.isnull()
# Out:
#    event    day  temperature  windspeed
# 0  False  False        False      False
# 1  False  False        False      False
# 2  False  False        False      False
# 3  False  False        False      False
# 4  False  False        False      False
# 5  False  False        False      False
# 6  False  False         True      False

# %%
df.isnull().sum()
# Out:
# event          0
# day            0
# temperature    1
# windspeed      0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#    event       day  temperature  windspeed
# 0   Rain  1/1/2017         32.0          6
# 1  Sunny  1/2/2017         35.0          7
# 2   Snow  1/3/2017         28.0          2
# 3   Snow  1/4/2017         24.0          7
# 4   Rain  1/5/2017         32.0          4
# 5  Sunny  1/6/2017         31.0          2
# 6   Rain  1/7/2017          0.0          3

# %%
df['temp_diff'] = df['temperature'] - df['temperature'].mean() #add new column

# %%
df
# Out:
#    event       day  temperature  windspeed  temp_diff
# 0   Rain  1/1/2017         32.0          6        6.0
# 1  Sunny  1/2/2017         35.0          7        9.0
# 2   Snow  1/3/2017         28.0          2        2.0
# 3   Snow  1/4/2017         24.0          7       -2.0
# 4   Rain  1/5/2017         32.0          4        6.0
# 5  Sunny  1/6/2017         31.0          2        5.0
# 6   Rain  1/7/2017          0.0          3      -26.0
